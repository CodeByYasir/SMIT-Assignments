# %% [markdown]
# Question 01: File Analysis and Word Search
# Instructions:
# 1.	Write a Python function named analyze_file that takes the name of a file as input and returns a dictionary containing the counts of characters, words, and lines in that file.
# 2.	Write another Python function named search_word that takes the name of a file and a word as input and returns the count of occurrences of that word in the file.
# 3.	Ensure that your functions handle file not found errors gracefully and return appropriate values in such cases.
# Submission:
# Additional Notes:
# •	Ensure that your functions are properly documented with clear descriptions of parameters, return values, and any assumptions made.
# •	Use appropriate error handling techniques to handle potential exceptions.
# •	Test your functions with different input files and scenarios to verify their correctness and robustness.

# %%
def analyze_file(file_name):
    # file handling
    try:
        with open(file_name, 'r') as file:
            lines = file.readlines()
     
        num_lines = len(lines)
        num_words = sum(len(line.split()) for line in lines)
        num_chars = sum(len(line) for line in lines)
        # return
        return {
            'characters': num_chars,
            'words': num_words,
            'lines': num_lines
        }
    except FileNotFoundError:
        print(f"Error: The file '{file_name}' was not found.")
        return None
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        return None
# another function for search words

def search_word(file_name, word):
    try:
        with open(file_name, 'r') as file:
            content = file.read()
        
        # Counting occurrences
        word_count = content.split().count(word)
        
        return word_count
    except FileNotFoundError:
        print(f"Error: The file '{file_name}' was not found.")
        return -1
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        return -1

# Testing the functions
if __name__ == "__main__":
    file_analysis = analyze_file('sample.txt')
    if file_analysis:
        print("File Analysis:", file_analysis)
    occurrences = search_word('sample.txt', 'Python')
    if occurrences != -1:
        print(f"The word 'Python' occurs {occurrences} times in the file.")
# Out:
# File Analysis: {'characters': 65, 'words': 13, 'lines': 1}
# The word 'Python' occurs 1 times in the file.

# %% [markdown]
# Question 2: Library Management System using Python OOP

# %%
class Book:
    def __init__(self, title, author, isbn):
        self.title = title
        self.author = author
        self.isbn = isbn
        self.is_borrowed = False

    def borrow(self):
        if not self.is_borrowed:
            self.is_borrowed = True
            print(f"The book '{self.title}' has been borrowed.")
        else:
            print(f"The book '{self.title}' is already borrowed.")

    def return_book(self):
        if self.is_borrowed:
            self.is_borrowed = False
            print(f"The book '{self.title}' has been returned.")
        else:
            print(f"The book '{self.title}' was not borrowed.")


class DigitalBook(Book):
    def __init__(self, title, author, isbn, file_format):
        super().__init__(title, author, isbn)
        self.file_format = file_format

    def borrow(self):
        super().borrow()
        if self.is_borrowed:
            print(f"Access the digital book '{self.title}' online in {self.file_format} format.")


class AudioBook(Book):

    def __init__(self, title, author, isbn, duration):
        super().__init__(title, author, isbn)
        self.duration = duration  # in hours

    def borrow(self):

        super().borrow()
        if self.is_borrowed:
            print(f"Stream the audiobook '{self.title}' (Duration: {self.duration} hours).")


class User:

    def __init__(self, user_id, name):
        self.user_id = user_id
        self.name = name
        self.__borrowed_books = []  # Encapsulated attribute

    def borrow_book(self, book):

        if book.is_borrowed:
            print(f"Sorry, '{book.title}' is already borrowed.")
        else:
            book.borrow()
            self.__borrowed_books.append(book)

    def return_book(self, book):

        if book in self.__borrowed_books:
            book.return_book()
            self.__borrowed_books.remove(book)
        else:
            print(f"The book '{book.title}' is not in the borrowed list.")

    def get_borrowed_books(self):

        return [book.title for book in self.__borrowed_books]


class Library:
    def __init__(self, name):
        self.name = name
        self.books = []
        self.users = []

    def add_book(self, book):
        self.books.append(book)
        print(f"The book '{book.title}' has been added to the library.")

    def register_user(self, user):
        self.users.append(user)
        print(f"The user '{user.name}' has been registered.")

    def lend_book(self, user_id, isbn):
        user = self.find_user(user_id)
        book = self.find_book(isbn)

        if user and book:
            user.borrow_book(book)
        elif not user:
            print(f"No user found with ID: {user_id}")
        elif not book:
            print(f"No book found with ISBN: {isbn}")

    def receive_return(self, user_id, isbn):
        user = self.find_user(user_id)
        book = self.find_book(isbn)

        if user and book:
            user.return_book(book)
        elif not user:
            print(f"No user found with ID: {user_id}")
        elif not book:
            print(f"No book found with ISBN: {isbn}")

    def find_user(self, user_id):
        for user in self.users:
            if user.user_id == user_id:
                return user
        return None

    def find_book(self, isbn):
        for book in self.books:
            if book.isbn == isbn:
                return book
        return None

    # Create a library
    my_library = Library("City Library")

    # Create some books
    book1 = Book("1984", "Yasir Ahmed", "12345")
    book2 = DigitalBook("Jadugar", "GulKhan", "67890", "PDF")
    book3 = AudioBook("Janaan", "Zardari", "11223", 5.5)

    # Add books to the library
    my_library.add_book(book1)
    my_library.add_book(book2)
    my_library.add_book(book3)

    # Register some users
    user1 = User("U001", "Yasir")
    user2 = User("U002", "Saqib")

    my_library.register_user(user1)
    my_library.register_user(user2)

    # User borrows books
    my_library.lend_book("U001", "12345")  
    my_library.lend_book("U002", "67890") 

    # Trying to borrow an already borrowed book
    my_library.lend_book("U001", "12345")  # Alice tries to borrow 1984 again

    # User returns books
    my_library.receive_return("U001", "12345")  # Alice returns 1984

    # Check borrowed books
    print(f"Alice's borrowed books: {user1.get_borrowed_books()}")
    print(f"Bob's borrowed books: {user2.get_borrowed_books()}")
# Out:
# The book '1984' has been added to the library.
# The book 'Jadugar' has been added to the library.
# The book 'Janaan' has been added to the library.
# The user 'Yasir' has been registered.
# The user 'Saqib' has been registered.
# The book '1984' has been borrowed.
# The book 'Jadugar' has been borrowed.
# Access the digital book 'Jadugar' online in PDF format.
# Sorry, '1984' is already borrowed.
# The book '1984' has been returned.
# Alice's borrowed books: []
# Bob's borrowed books: ['Jadugar']
